# %% [markdown]
# # L9: Building LLM prompts with variables

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.

# %%
from helper_functions import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:

# %%
print_llm_response("What is the capital of France?")
# Out:
# The capital of France is Paris.

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# At 3.0 years old, Otto Matic would be considered an adult dog. He would likely have high energy levels, be playful, curious, and eager to explore. This stage is characterized by peak physical abilities and mental maturity. Otto Matic may enjoy activities such as running, playing fetch, and learning new tricks. It's important to provide him with regular exercise, mental stimulation, and social interaction to keep him happy and healthy.

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>Congratulations 🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.

# %%
driver = "sajag"
drivers_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Earth"

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {drivers_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# Once upon a time, in the bustling town of Dino Valley, a sajag named Sparky dreamed of becoming the Earth Champion Cup winner. The prestigious race was just around the corner, and Sparky had been training tirelessly with his trusty dinosaur car, Rainbow Raptor.
#
# On the day of the race, excitement filled the air as the colorful, asymmetric dinosaur cars lined up at the starting line. Sparky could feel his heart pounding with anticipation as he revved up Rainbow Raptor's engine.
#
# The race began, and the cars zoomed down the winding track, dodging obstacles and speeding through sharp turns. Sparky and Rainbow Raptor were neck and neck with their competitors, but Sparky's determination never wavered.
#
# As they approached the final stretch, a sudden burst of speed propelled Rainbow Raptor ahead of the pack. Sparky could see the finish line in sight, and with a burst of energy, he pushed Rainbow Raptor to its limits.
#
# In a thrilling photo finish, Sparky and Rainbow Raptor crossed the finish line first, claiming the Earth Champion Cup in a spectacular victory. The crowd erupted into cheers as Sparky and Rainbow Raptor basked in their well-deserved glory.
#
# From that day on, Sparky became a hero in Dino Valley, inspiring young sajags and dinosaur car enthusiasts alike to chase their dreams with passion and perseverance. And as for Rainbow Raptor, it became a legend in its own right, known far and wide as the most colorful and fastest dinosaur car in all the land.
#
# And so, Sparky and Rainbow Raptor's story of triumph and friendship lived on, a shining example of what can be achieved when you believe in yourself and never give up.

# %% [markdown]
# ## Extra practice
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# <b>Feel free to use the chatbot if you need help.</b>

# %%
# Fix this code
favorite_book = "1001 Ways to Wear a Hat"
second_fav_book = "2002 Ways to Wear a Scarf" 
print(f"My most favorite book is {favorite_book}, but I also like {second_fav_book}")
# Out:
# My most favorite book is 1001 Ways to Wear a Hat, but I also like 2002 Ways to Wear a Scarf

# %%
# Make variables for your favorite game, movie, and food.
# Then use print_llm_response to ask the LLM to recommend you
# a new song to listen to based on your likes.
fav_game = "Walking Dead"
fav_movie = "Border"
fav_food = "Chowmein"
print_llm_response(f"""
Recommend me a new hindi song to listen to based on my likes of favourite game:
{fav_game}, favourite movie: {fav_movie} and favourite food: {fav_food}
""")
# Out:
# I recommend you listen to the song "Zinda" from the movie "Bhaag Milkha Bhaag."
